# %%
import os
import json
import re
import requests
from urllib.parse import urlparse
import concurrent.futures
from bs4 import BeautifulSoup, XMLParsedAsHTMLWarning
from datetime import datetime
import dateutil.parser
import warnings
from dateutil.tz import gettz
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry

# Suppress specific warnings
warnings.filterwarnings("ignore", category=XMLParsedAsHTMLWarning)

# Mapping for unknown timezones
tzinfos = {
    'EDT': gettz('America/New_York'),
    'EST': gettz('America/New_York'),
    'PST': gettz('America/Los_Angeles'),
    'PDT': gettz('America/Los_Angeles'),
    'IST': gettz('Asia/Kolkata'),
    'PT': gettz('America/Los_Angeles')
}

def parse_date(date_str):
    try:
        return dateutil.parser.parse(date_str, fuzzy=True, tzinfos=tzinfos).strftime('%Y-%m-%d')
    except:
        return None

def calculate_weight(published_date):
    if not published_date:
        return 0.5  # Default weight for unknown dates
    
    date = datetime.strptime(published_date, '%Y-%m-%d')
    today = datetime.now()
    age = (today - date).days
    
    if age <= 30:  # Very recent (last month)
        return 1.0
    elif age <= 365:  # Within the last year
        return 0.8
    elif age <= 3*365:  # Within the last 3 years
        return 0.6
    else:  # Older than 3 years
        return 0.4

def extract_date(url, html_content, content_type):
    if 'xml' in content_type.lower():
        soup = BeautifulSoup(html_content, 'xml')
    else:
        soup = BeautifulSoup(html_content, 'lxml')

    potential_dates = []

    # 1. Check meta tags
    meta_tags = soup.find_all('meta')
    for tag in meta_tags:
        if tag.get('property') in ['article:published_time', 'og:published_time', 'pubdate', 'datePublished', 'date']:
            potential_dates.append(tag.get('content'))

    # 2. Check LD+JSON
    ld_json = soup.find_all('script', type='application/ld+json')
    for script in ld_json:
        try:
            data = json.loads(script.string)
            if isinstance(data, list):
                data = data[0]
            date = data.get('datePublished') or data.get('dateCreated') or data.get('dateModified')
            if date:
                potential_dates.append(date)
        except:
            continue

    # 3. Check time tags
    time_tags = soup.find_all('time')
    for tag in time_tags:
        if tag.has_attr('datetime'):
            potential_dates.append(tag['datetime'])
        elif tag.string:
            potential_dates.append(tag.string)

    # 4. Look for date patterns in text
    text = soup.get_text()
    date_patterns = [
        r'\\d{4}-\\d{2}-\\d{2}',
        r'\\d{2}/\\d{2}/\\d{4}',
        r'\\d{2}-\\d{2}-\\d{4}',
        r'\\b(?:January|February|March|April|May|June|July|August|September|October|November|December)\\s+\\d{1,2},?\\s+\\d{4}\\b',
        r'\\b(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)\\s+\\d{1,2},?\\s+\\d{4}\\b'
    ]
    for pattern in date_patterns:
        matches = re.findall(pattern, text)
        potential_dates.extend(matches)

    # 5. Check URL for date
    url_date_patterns = [
        r'/(\\d{4}/\\d{2}/\\d{2})/',
        r'(\\d{4}-\\d{2}-\\d{2})',
        r'(\\d{2}-\\d{2}-\\d{4})',
    ]
    for pattern in url_date_patterns:
        match = re.search(pattern, url)
        if match:
            potential_dates.append(match.group(1))

    # Parse and validate all potential dates
    valid_dates = [parse_date(date) for date in potential_dates if parse_date(date)]
    
    if valid_dates:
        # Return the oldest date found
        return min(valid_dates)
    
    return None

def analyze_url(url):
    try:
        parsed = urlparse(url)
        domain = parsed.netloc.lower()

        known_domains = {
            'twitter.com': 'Twitter',
            'x.com': 'Twitter',
            'github.com': 'GitHub',
            'youtube.com': 'YouTube',
            'youtu.be': 'YouTube',
            'linkedin.com': 'LinkedIn',
            'facebook.com': 'Facebook',
            'fb.com': 'Facebook',
            'instagram.com': 'Instagram',
            'reddit.com': 'Reddit',
            'medium.com': 'Medium',
            'stackoverflow.com': 'Stack Overflow',
            'wikipedia.org': 'Wikipedia',
            'amazon.com': 'Amazon',
            'dropbox.com': 'Dropbox',
        }
        
        for known_domain, site_type in known_domains.items():
            if known_domain in domain:
                return site_type, None

        # Setting up a retry strategy
        session = requests.Session()
        retries = Retry(total=5, backoff_factor=0.1, status_forcelist=[500, 502, 503, 504])
        session.mount('http://', HTTPAdapter(max_retries=retries))
        session.mount('https://', HTTPAdapter(max_retries=retries))

        headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
        response = session.get(url, headers=headers, timeout=10)
        content_type = response.headers.get('Content-Type', '').lower()
        
        published_date = extract_date(url, response.text, content_type)

        if 'text/html' in content_type or 'application/xhtml+xml' in content_type:
            return 'Web Page', published_date
        elif 'application/pdf' in content_type:
            return 'PDF', published_date
        elif any(img_type in content_type for img_type in ['image/jpeg', 'image/png', 'image/gif']):
            return 'Image', published_date
        elif 'application/json' in content_type:
            return 'API', published_date
        elif any(doc_type in content_type for doc_type in ['msword', 'vnd.openxmlformats-officedocument', 'vnd.ms-excel']):
            return 'Document', published_date
        else:
            return 'Unknown', published_date
    except Exception as e:
        return f'Error: {str(e)}', None

def process_url(url):
    url_type, published_date = analyze_url(url)
    weight = calculate_weight(published_date)
    return {
        "url": url,
        "url_type": url_type,
        "published_date": published_date,
        "weight": weight
    }

def update_json_with_dates(json_file):
    with open(json_file, 'r', encoding='utf-8') as infile:
        data = json.load(infile)
    
    hyperlinks = data.get('hyperlinks', [])
    
    with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:
        results = list(executor.map(process_url, hyperlinks))
    
    data['hyperlinks'] = results
    
    with open(json_file, 'w', encoding='utf-8') as outfile:
        json.dump(data, outfile, indent=2)

    print(f"Updated JSON file: {json_file}")

def process_all_json_files(directory):
    json_files = [f for f in os.listdir(directory) if f.endswith('.json')]
    total_files = len(json_files)
    processed_files = 0
    total_urls = 0
    total_dates_extracted = 0

    for json_file in json_files:
        full_path = os.path.join(directory, json_file)
        update_json_with_dates(full_path)
        
        # Count URLs and extracted dates
        with open(full_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
            urls = data.get('hyperlinks', [])
            total_urls += len(urls)
            total_dates_extracted += sum(1 for url in urls if url['published_date'])
        
        processed_files += 1
        print(f"Processed {processed_files}/{total_files} files")

    print(f"\\nTotal JSON files processed: {total_files}")
    print(f"Total URLs processed: {total_urls}")
    print(f"Total URLs with extracted dates: {total_dates_extracted}")

# Directory containing JSON files
json_directory = r'C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown'

# Process all JSON files in the directory
process_all_json_files(json_directory)
# Out:
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Agentic Metaverse for Global Creatives.md.meta.json
# Processed 1/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Agentic Mycelia.md.meta.json
# Processed 2/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Agents.md.meta.json
# Processed 3/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\AI Adoption.md.meta.json
# Processed 4/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\AI Companies.md.meta.json
# Processed 5/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Ai in Games.md.meta.json
# Processed 6/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\AI privacy at the 2024 Olympics.md.meta.json
# Processed 7/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\AI Risks.md.meta.json
# Processed 8/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\AI Video.md.meta.json
# Processed 9/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Algorithmic Bias and Variance.md.meta.json
# Processed 10/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\AnimateDiff.md.meta.json
# Processed 11/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Anthropic Claude.md.meta.json
# Processed 12/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Apple.md.meta.json
# Processed 13/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Artificial Intelligence.md.meta.json
# Processed 14/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\artificial superintelligence.md.meta.json
# Processed 15/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Automated Podcast Project.md.meta.json
# Processed 16/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Base models.md.meta.json
# Processed 17/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Bitcoin As Money.md.meta.json
# Processed 18/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Bitcoin ETF.md.meta.json
# Processed 19/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Bitcoin Technical Overview.md.meta.json
# Processed 20/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Bitcoin Value Proposition.md.meta.json
# Processed 21/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Bitcoin.md.meta.json
# Processed 22/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Blender.md.meta.json
# Processed 23/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Blockchain.md.meta.json
# Processed 24/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\BTC Layer 3.md.meta.json
# Processed 25/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Calculating Empires.md.meta.json
# Processed 26/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\California AI bill.md.meta.json
# Processed 27/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Cashu.md.meta.json
# Processed 28/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\ChatGPT.md.meta.json
# Processed 29/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Client side DCO.md.meta.json
# Processed 30/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Coding support.md.meta.json
# Processed 31/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\collaborative.md.meta.json
# Processed 32/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Comfy UI for Fashion and Brands.md.meta.json
# Processed 33/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\ComfyUI.md.meta.json
# Processed 34/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Comparison of GPT4 and Gemini Ultra.md.meta.json
# Processed 35/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Comparison of SDXL and Midjourney v6.md.meta.json
# Processed 36/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Competition in AI.md.meta.json
# Processed 37/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Conspiracies.md.meta.json
# Processed 38/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\contents.md.meta.json
# Processed 39/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Controlnet and similar.md.meta.json
# Processed 40/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Convergence.md.meta.json
# Processed 41/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Courses and Training.md.meta.json
# Processed 42/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Create RAG from public pages.md.meta.json
# Processed 43/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Cyber security and Cryptography.md.meta.json
# Processed 44/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Cyber Security and Military.md.meta.json
# Processed 45/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\cypherpunk.md.meta.json
# Processed 46/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Death of the Internet.md.meta.json
# Processed 47/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Decentralised Web.md.meta.json
# Processed 48/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Deep Learning.md.meta.json
# Processed 49/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Deepfakes and fraudulent content.md.meta.json
# Processed 50/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Deepmind.md.meta.json
# Processed 51/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Definitions and frameworks for Metaverse.md.meta.json
# Processed 52/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Depth Estimation.md.meta.json
# Processed 53/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Diagrams as Code.md.meta.json
# Processed 54/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Diffusion Models.md.meta.json
# Processed 55/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Digital Asset Risks.md.meta.json
# Processed 56/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Digital Objects.md.meta.json
# Processed 57/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Digital Society Surveillance.md.meta.json
# Processed 58/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Distributed Identity.md.meta.json
# Processed 59/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\ecash.md.meta.json
# Processed 60/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Education.md.meta.json
# Processed 61/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Energy and Power.md.meta.json
# Processed 62/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Ethereum.md.meta.json
# Processed 63/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\EU AI Act.md.meta.json
# Processed 64/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Evaluation and leaderboards.md.meta.json
# Processed 65/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Facebook Meta.md.meta.json
# Processed 66/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\flossverse.md.meta.json
# Processed 67/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\GANs.md.meta.json
# Processed 68/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Gaussian splatting and Similar.md.meta.json
# Processed 69/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Gemini.md.meta.json
# Processed 70/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Geopolitical hot takes.md.meta.json
# Processed 71/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Global Inequality.md.meta.json
# Processed 72/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Gold.md.meta.json
# Processed 73/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Hardware and Edge.md.meta.json
# Processed 74/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Human tracking and SLAM capture.md.meta.json
# Processed 75/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Human vs AI.md.meta.json
# Processed 76/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Humans, Avatars , Character.md.meta.json
# Processed 77/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Hyper personalisation.md.meta.json
# Processed 78/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\infrastructure.md.meta.json
# Processed 79/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Inpainting.md.meta.json
# Processed 80/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Introduction to me.md.meta.json
# Processed 81/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\IPAdapter.md.meta.json
# Processed 82/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Jailbreaking.md.meta.json
# Processed 83/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Knowhere.md.meta.json
# Processed 84/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Knowledge Management and Graphing.md.meta.json
# Processed 85/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Landscape.md.meta.json
# Processed 86/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Large language models.md.meta.json
# Processed 87/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\latent space.md.meta.json
# Processed 88/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Layoff tracker and threatened roles.md.meta.json
# Processed 89/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Lead Poisoning Hypothesis.md.meta.json
# Processed 90/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Leopold Aschenbrenner.md.meta.json
# Processed 91/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\license.md.meta.json
# Processed 92/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Lightning and Similar L2.md.meta.json
# Processed 93/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Llama.md.meta.json
# Processed 94/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Machine Learning.md.meta.json
# Processed 95/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Medical AI.md.meta.json
# Processed 96/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Metaverse and Spatial Risks.md.meta.json
# Processed 97/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Metaverse and Telecollaboration.md.meta.json
# Processed 98/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Metaverse as Markets.md.meta.json
# Processed 99/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Metaverse Ontology.md.meta.json
# Processed 100/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Microsoft CoPilot.md.meta.json
# Processed 101/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Microsoft Work Trends Impact 2024.md.meta.json
# Processed 102/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Mixed reality.md.meta.json
# Processed 103/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Model Optimisation and Performance.md.meta.json
# Processed 104/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Money.md.meta.json
# Processed 105/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Multi Agent RAG scrapbook.md.meta.json
# Processed 106/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\multimodal.md.meta.json
# Processed 107/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Music and audio.md.meta.json
# Processed 108/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\National Industrial Centre for Virtual Environments.md.meta.json
# Processed 109/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Norbert Wiener.md.meta.json
# Processed 110/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\nostr.md.meta.json
# Processed 111/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\NVIDIA Omniverse.md.meta.json
# Processed 112/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Octave Multi Model Laboratory.md.meta.json
# Processed 113/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Open Generative AI tools.md.meta.json
# Processed 114/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\OpenAI.md.meta.json
# Processed 115/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Overview of Machine Learning Techniques.md.meta.json
# Processed 116/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\p(doom).md.meta.json
# Processed 117/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Parametric.md.meta.json
# Processed 118/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Politics, Law, Privacy.md.meta.json
# Processed 119/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Product and Risk Management.md.meta.json
# Processed 120/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Product Design.md.meta.json
# Processed 121/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Prompt Engineering.md.meta.json
# Processed 122/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Proprietary AI Video.md.meta.json
# Processed 123/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Proprietary Image Generation.md.meta.json
# Processed 124/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Proprietary Large Language Models.md.meta.json
# Processed 125/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Proprietary Video VP & 3D.md.meta.json
# Processed 126/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Python to build RAG data page.md.meta.json
# Processed 127/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Python to list nodes.md.meta.json
# Processed 128/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\PythonSample1.md.meta.json
# Processed 129/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\qlora.md.meta.json
# Processed 130/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\RAG.md.meta.json
# Processed 131/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Recent Projects.md.meta.json
# Processed 132/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\relighting.md.meta.json
# Processed 133/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Research Tools.md.meta.json
# Processed 134/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Revision List.md.meta.json
# Processed 135/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\RGB and Client Side Validation.md.meta.json
# Processed 136/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Robin Hanson.md.meta.json
# Processed 137/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Robotics.md.meta.json
# Processed 138/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Safety and alignment.md.meta.json
# Processed 139/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Sam Hammond.md.meta.json
# Processed 140/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Scene Capture and Reconstruction.md.meta.json
# Processed 141/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Segmentation and Identification.md.meta.json
# Processed 142/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Semantic Web.md.meta.json
# Processed 143/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Singularity.md.meta.json
# Processed 144/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\SLAM.md.meta.json
# Processed 145/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Social contract and jobs.md.meta.json
# Processed 146/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Soon-Next-Later (AI futurology).md.meta.json
# Processed 147/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Spatial Computing.md.meta.json
# Processed 148/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Speech and voice.md.meta.json
# Processed 149/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Stable Coins.md.meta.json
# Processed 150/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Stable Diffusion.md.meta.json
# Processed 151/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\State of the art in AI.md.meta.json
# Processed 152/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\State Space and Other Approaches.md.meta.json
# Processed 153/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Suggested Reading Order.md.meta.json
# Processed 154/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Text to 3D and 4D.md.meta.json
# Processed 155/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Tim Reutermann.md.meta.json
# Processed 156/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Time Series Forecasting.md.meta.json
# Processed 157/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Tokenization.md.meta.json
# Processed 158/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Training and fine tuning.md.meta.json
# Processed 159/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Transformers.md.meta.json
# Processed 160/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Trust and Safety.md.meta.json
# Processed 161/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Tuesday 11th of June FRAME reporting.md.meta.json
# Processed 162/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Upscaling.md.meta.json
# Processed 163/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Vesuvian Scrolls.md.meta.json
# Processed 164/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Virtual Production.md.meta.json
# Processed 165/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Vision Pro.md.meta.json
# Processed 166/167 files
# Updated JSON file: C:\\Users\\lolic\\OneDrive\\Desktop\\work stuff\\MediaCity Immersive Innovation Hub(Dreamlab)\\WebScraping\\markdown\\MetaJson markdown\Visionflow.md.meta.json
# Processed 167/167 files
# \nTotal JSON files processed: 167
# Total URLs processed: 3838
# Total URLs with extracted dates: 147
